# %% [markdown]
# #### Importing all the required libraries to work on this project.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading the CSV files on which we need to perform the analysis.

# %%
all_sites = pd.read_csv('all_sites_scores.csv')
fandango_ratings = pd.read_csv('fandango_scrape.csv')

# %% [markdown]
# #### Exploring the Fandango DataFrame Properties and Head.

# %%
fandango_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango_ratings.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
fandango_ratings.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %% [markdown]
# #### Exploring the relationship between the popularity of the film and its rating.
# This can be done by plotting a scatterplot between Rating and Votes columns

# %%
fandango_ratings.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES'], dtype='object')

# %%
plt.figure(figsize=(8,3), dpi = 250)

sns.scatterplot(
    data = fandango_ratings,
    x = 'RATING',
    y = 'VOTES',
    c = 'green'
)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
fandango_ratings.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
plt.figure(figsize=(8,3), dpi = 250)

sns.scatterplot(
    data = fandango_ratings,
    x = 'STARS',
    y = 'VOTES',
    c = 'green'
)
# Out:
# <Axes: xlabel='STARS', ylabel='VOTES'>

# %% [markdown]
# #### Calculate the correlation between the columns.

# %%
fandango_ratings.corr(numeric_only = True).style.background_gradient('RdYlGn')
# Out:
# <style type="text/css">
# #T_42f20_row0_col0, #T_42f20_row1_col1, #T_42f20_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_42f20_row0_col1, #T_42f20_row1_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_42f20_row0_col2, #T_42f20_row1_col2, #T_42f20_row2_col0, #T_42f20_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42f20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42f20_level0_col0" class="col_heading level0 col0" >STARS</th>
#       <th id="T_42f20_level0_col1" class="col_heading level0 col1" >RATING</th>
#       <th id="T_42f20_level0_col2" class="col_heading level0 col2" >VOTES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42f20_level0_row0" class="row_heading level0 row0" >STARS</th>
#       <td id="T_42f20_row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %% [markdown]
# **TASK: Assuming that every row in the FILM title column has the same format:**
#
#     Film Title Name (Year)
#
# **Create a new column that is able to strip the year from the title strings and set this new column as YEAR**

# %%
fandango_ratings.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES'], dtype='object')

# %%
fandango_ratings.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango_ratings['YEAR'] = fandango_ratings['FILM'].apply(lambda x: x.split('(')[-1].split(')')[0])

# %%
fandango_ratings.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %% [markdown]
# **TASK: How many movies are in the Fandango DataFrame per year?**

# %%
fandango_ratings['YEAR'].value_counts()
# Out:
# YEAR
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: count, dtype: int64

# %% [markdown]
# **TASK: Visualize the count of movies per year with a plot:**

# %%
plt.figure(figsize=(3,2), dpi = 250)

sns.countplot(
    data = fandango_ratings,
    x = 'YEAR',
    hue = 'YEAR',
    legend = False,
    palette = 'Set1'
);

# %% [markdown]
# **TASK: What are the 10 movies with the highest number of votes?**

# %%
fandango_ratings.sort_values('VOTES', ascending=False).iloc[:10]
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# **TASK: How many movies have zero votes?**

# %%
fandango_ratings[fandango_ratings['VOTES'] == 0]['VOTES'].value_counts()
# Out:
# VOTES
# 0    69
# Name: count, dtype: int64

# %% [markdown]
# **TASK: Create DataFrame of only reviewed films by removing any films that have zero votes.**

# %%
reviewed_films = fandango_ratings[fandango_ratings['VOTES'] > 0]

# %%
reviewed_films['VOTES'].value_counts()
# Out:
# VOTES
# 1       35
# 4       22
# 2       19
# 5       15
# 8       13
#         ..
# 1651     1
# 1501     1
# 1462     1
# 1430     1
# 482      1
# Name: count, Length: 209, dtype: int64

# %% [markdown]
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different than the rating shown to a user. Let's visualize this difference in distributions.**
#
# **TASK: Create a KDE plot (or multiple kdeplots) that displays the distribution of ratings that are displayed (STARS) versus what the true rating was from votes (RATING). Clip the KDEs to 0-5.**

# %%
reviewed_films.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %%
plt.figure(figsize=(10,4), dpi = 250)
plt.xlim(0,5)

sns.set_style(style = 'white')
sns.kdeplot(
    data = reviewed_films,
    x = 'RATING',
    #bw_method = 0.15,
    label = 'True Rating',
    color = '#00bfff',
    fill = True
)

sns.kdeplot(
    data = reviewed_films,
    x = 'STARS',
    #bw_method = 0.14,
    label = 'Stars Displayed',
    color = '#ffbf00',
    fill = True
)

plt.legend(bbox_to_anchor = (1.25, 1));

# %% [markdown]
# **TASK: Let's now actually quantify this discrepancy. Create a new column of the different between STARS displayed versus true RATING. Calculate this difference with STARS-RATING and round these differences to the nearest decimal point.**

# %%
fandango_ratings['STARS_DIFF'] = round(abs(fandango_ratings['RATING'] - fandango_ratings['STARS']) ,1)

# %%
fandango_ratings
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR  \
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
#      STARS_DIFF
# 0           0.1
# 1           0.0
# 2           0.2
# 3           0.2
# 4           0.0
# ..          ...
# ...

# %% [markdown]
# **TASK: Create a count plot to display the number of times a certain difference occurs:**

# %%
plt.figure(figsize=(8,3), dpi = 250)
plt.ylim(0,200)

sns.set_style(style = 'white')
ax = sns.countplot(
    data = fandango_ratings,
    x = 'STARS_DIFF',
    hue = 'STARS_DIFF',
    legend = False,
    palette = 'Set1'
)

for bar in ax.containers:
    ax.bar_label(bar, fmt='%d', weight = 'bold')

plt.show()

# %% [markdown]
# **TASK: We can see from the plot that one movie was displaying over a 1 star difference than its true rating! What movie had this close to 1 star differential?**

# %%
fandango_ratings[fandango_ratings['STARS_DIFF'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ## Part Two: Comparison of Fandango Ratings to Other Sites

# %% [markdown]
# **TASK: Explore the all_sites DataFrame columns, info, description.**

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %% [markdown]
# ### Rotten Tomatoes
#
# Let's first take a look at Rotten Tomatoes. RT has two sets of reviews, their critics reviews (ratings published by official critics) and user reviewsws.

# %% [markdown]
# **TASK: Create a scatterplot exploring the relationship between RT Critic reviews and RT User reviews.**

# %%
plt.figure(figsize=(10,4), dpi = 250)

sns.set_style(style = 'white')
sns.scatterplot(
    data = all_sites,
    x = 'RottenTomatoes',
    y = 'RottenTomatoes_User',
    c = 'red'
);

# %% [markdown]
# Let's quantify this difference by comparing the critics ratings and the RT User ratings. We will calculate this with RottenTomatoes-RottenTomatoes_User. Note: Rotten_Diff here is Critics - User Score. So values closer to 0 means aggrement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.er

# %% [markdown]
# **TASK: Create a new column based off the difference between critics ratings and users ratings for Rotten Tomatoes. Calculate this with RottenTomatoes-RottenTomatoes_User**

# %%
all_sites['Rotten_Diff'] = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %% [markdown]
# Let's now compare the overall mean difference. Since we're dealing with differences that could be negative or positive, first take the absolute value of all the differences, then take the mean. This would report back on average to absolute difference between the critics rating versus the user rating.e.

# %% [markdown]
# **TASK: Calculate the Mean Absolute Difference between RT scores and RT User scores as described above.**

# %%
all_sites['Rotten_Diff'].abs().mean()
# Out:
# 15.095890410958905

# %% [markdown]
# **TASK: Plot the distribution of the differences between RT Critics Score and RT User Score. There should be negative values in this distribution plot. Feel free to use KDE or Histograms to display this distribution.**

# %%
plt.figure(figsize=(10,4), dpi = 250)
plt.title('RT Critics Score minus RT User Score')

sns.histplot(
    data = all_sites,
    x = 'Rotten_Diff',
    bins = 25,
    kde = True,
    color = 'red'
);

# %% [markdown]
# **TASK: Now create a distribution showing the absolute value difference between Critics and Users on Rotten Tomatoes.**

# %%
plt.figure(figsize=(10,4), dpi = 250)
plt.title('Abs Difference between RT Critics and RT User Scores')

sns.histplot(
    data = all_sites,
    x = all_sites['Rotten_Diff'].abs(),
    bins = 25,
    color = 'red',
    kde = True
);

# %% [markdown]
# **Let's find out which movies are causing the largest differences. First, show the top 5 movies with the largest negative difference between Users and RT critics. Since we calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %% [markdown]
# **TASK: What are the top 5 movies users rated higher than critics on average:**

# %%
print('\n\033[1mUsers love, but Critics hate\033[0m\n')
all_sites[all_sites['Rotten_Diff'] < 0].sort_values('Rotten_Diff')[['FILM', 'Rotten_Diff']][:5]
# Out:
# Users love, but Critics hate
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 134    The Longest Ride (2015)          -42
# 105    Hitman: Agent 47 (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **TASK: Now show the top 5 movies critics scores higher than users on average.**

# %%
print('\n\033[1mCritics love, but Users hate\033[0m\n')
all_sites[all_sites['Rotten_Diff']>0].sort_values('Rotten_Diff', ascending = False)[['FILM', 'Rotten_Diff']][:5]
# Out:
# Critics love, but Users hate
#                                    FILM  Rotten_Diff
# 69                    Mr. Turner (2014)           42
# 112                   It Follows (2015)           31
# 115            While We're Young (2015)           31
# 145  Kumiko, The Treasure Hunter (2015)           24
# 40     I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## MetaCritic

# %% [markdown]
# **TASK: Display a scatterplot of the Metacritic Rating versus the Metacritic User rating.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %%
plt.figure(figsize=(10,5), dpi = 200)
plt.xlim(0,100)
plt.ylim(0,10)

sns.set_style(style = 'ticks')
sns.scatterplot(
    all_sites,
    x = 'Metacritic',
    y = 'Metacritic_User',
    c = 'orange'
);

# %% [markdown]
# ## IMDB

# %% [markdown]
# **Finally let's explore IMDB. Notice that both Metacritic and IMDB report back vote counts. Let's analyze the most popular movies.**

# %% [markdown]
# **TASK: Create a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %%
plt.figure(figsize=(10,4), dpi = 200)

sns.set_style(style = 'ticks')
sns.scatterplot(
    all_sites,
    x = 'Metacritic_user_vote_count',
    y = 'IMDB_user_vote_count',
    c = 'green'
);

# %% [markdown]
# **Notice there are two outliers here. The movie with the highest vote count on IMDB only has about 500 Metacritic ratings. What is this movie?**

# %% [markdown]
# **TASK: What movie has the highest IMDB user vote count?**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %%
all_sites.iloc[[all_sites['IMDB_user_vote_count'].idxmax()]]
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **TASK: What movie has the highest Metacritic User Vote count?**

# %%
all_sites.iloc[[all_sites['Metacritic_user_vote_count'].idxmax()]]
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ## Fandango Scores vs. All Sites.

# %% [markdown]
# **Finally let's begin to explore whether or not Fandango artificially displays higher ratings than warranted to boost ticket sales.**
#
# **TASK: Combine the Fandango Table with the All Sites table. Not every movie in the Fandango table is in the All Sites table, since some Fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so do an inner merge to merge together both DataFrames based on the FILM columns.**

# %%
fandango_ratings.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %%
combined_df = pd.merge(
    left = fandango_ratings.drop('STARS_DIFF', axis = 1),
    right= all_sites,
    how = 'inner',
    on = 'FILM'
)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
combined_df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# ...

# %% [markdown]
# **Normalize columns to Fandango STARS and RATINGS 0-5**
# Notice that RT,Metacritic, and IMDB don't use a score between 0-5 stars like Fandango does. In order to do a fair comparison, we need to normalize these values so they all fall between 0-5 stars and the relationship between reviews stays the sameis.

# %% [markdown]
# **TASK: Create new normalized columns for all ratings so they match up within the 0-5 star range shown on Fandango. There are many ways to do this.**

# %%
combined_df.head(2)
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# 1                        1281                241807          -10

# %%
combined_df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff'],
#       dtype='object')

# %%
combined_df['RT_Norm'] = round(combined_df['RottenTomatoes'] / 20, 1)
combined_df['RTU_Norm'] = round(combined_df['RottenTomatoes_User'] / 20, 1)
combined_df['Meta_Norm'] = round(combined_df['Metacritic'] / 20, 1)
combined_df['Meta_U_Norm'] = round(combined_df['Metacritic_User'] / 2, 1)
combined_df['IMDB_Norm'] = round(combined_df['IMDB'] / 2, 1)

# %%
combined_df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      1.2
# ...

# %%
combined_df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff',
#        'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm'],
#       dtype='object')

# %% [markdown]
# **TASK: Now create a norm_scores DataFrame that only contains the normalizes ratings. Include both STARS and RATING from the original Fandango table.**

# %%
normalized_scores_df = combined_df[['STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
normalized_scores_df.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3          1.6        2.1
# 1    4.5     4.5      3.6       4.0        3.0          3.5        3.6
# 2    5.0     4.8      3.6       4.2        3.6          3.3        3.7
# 3    5.0     4.8      4.0       4.2        3.4          3.4        3.7
# 4    4.5     4.5      4.9       4.5        4.7          4.4        4.3

# %% [markdown]
# ## Comparing Distribution of Scores Across Sites

# %% [markdown]
# Now the moment of truth! Does Fandango display abnormally high ratings? We already know it pushs displayed RATING higher than STARS, but are the ratings themselves higher than average?
#
# **TASK: Create a plot comparing the distributions of normalized ratings across all sites. There are many ways to do this, but explore the Seaborn KDEplot docs for some simple ways to quickly show this. Don't worry if your plot format does not look exactly the same as ours, as long as the differences in distribution are clear.**

# %%
plt.figure(figsize = (10, 4), dpi = 200)
plt.xlim(0,5)

sns.kdeplot(normalized_scores_df, fill = True, legend = True, lw = 0.7, palette = 'Set1');

# %% [markdown]
# **Clearly Fandango has an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**

# %% [markdown]
# **TASK: Create a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango.**

# %%
plt.figure(figsize=(10, 4), dpi = 200)
plt.xlim(0,5)

sns.kdeplot(
    normalized_scores_df[['STARS', 'RT_Norm']],
    fill = True,
    lw = 0.7,
    palette = 'Set1'
);

# %% [markdown]
# ### OPTIONAL TASK: Create a histplot comparing all normalized scores.

# %%
plt.figure(figsize=(10, 4), dpi = 200)

sns.histplot(normalized_scores_df, bins = 50);

# %% [markdown]
# **How are the worst movies rated across all platforms?**.

# %% [markdown]
# **TASK: Create a clustermap visualization of all normalized scores. Note the differences in ratings, highly rated movies should be clustered together versus poorly rated movies. Note: This clustermap does not need to have the FILM titles as the index, feel free to drop it for the clustermap.**

# %%
sns.clustermap(normalized_scores_df);

# %% [markdown]
# **TASK: Clearly Fandango is rating movies much higher than other sites, especially considering that it is then displaying a rounded up version of the rating. Let's examine the top 10 worst movies. Based off the Rotten Tomatoes Critic Ratings, what are the top 10 lowest rated movies? What are the normalized scores across all platforms for these movies? You may need to add the FILM column back in to your DataFrame of normalized scores to see the results.**

# %%
normalized_scores_df = combined_df[['FILM', 'STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
top_10_worst_movies = normalized_scores_df.sort_values('RT_Norm')[0:10]

# %%
top_10_worst_movies
# Out:
#                               FILM  STARS  RATING  RT_Norm  RTU_Norm  \
# 49   Paul Blart: Mall Cop 2 (2015)    3.5     3.5      0.2       1.8
# 25                  Taken 3 (2015)    4.5     4.1      0.4       2.3
# 28           Fantastic Four (2015)    3.0     2.7      0.4       1.0
# 84         Hitman: Agent 47 (2015)    4.0     3.9      0.4       2.4
# 54              Hot Pursuit (2015)    4.0     3.7      0.4       1.8
# 50        The Boy Next Door (2015)    4.0     3.6      0.5       1.8
# 109       The Vatican Tapes (2015)    3.0     2.9      0.6       1.0
# 88                 The Loft (2015)    4.0     3.6      0.6       2.0
# 87      Unfinished Business (2015)    3.5     3.2      0.6       1.4
# 83               Sinister 2 (2015)    3.5     3.3      0.6       1.7
#
#      Meta_Norm  Meta_U_Norm  IMDB_Norm
# 49         0.6          1.2        2.2
# 25         1.3          2.3        3.0
# 28         1.4          1.2        2.0
# 84         1.4          1.6        3.0
# ...

# %% [markdown]
# **FINAL TASK: Visualize the distribution of ratings across all sites for the top 10 worst movies.**

# %%
plt.figure(figsize = (10, 4), dpi = 200)

sns.kdeplot(
    top_10_worst_movies,
    lw = 0.7,
    fill = True,
    palette = 'Set1'
);

# %% [markdown]
# **Final thoughts: Wow! Fandango is showing around 3-4 star ratings for films that are clearly bad! Notice the biggest offender, Taken 3!. Fandango is displaying 4.5 stars on their site for a film with an average rating of 1.86 across the other platforms!**

# %%
from PIL import Image

img = Image.open('taken.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x219 at 0x1BB152A5120>

# %%
top_10_worst_movies.sort_values('STARS', ascending = False).iloc[0]
# Out:
# FILM           Taken 3 (2015)
# STARS                     4.5
# RATING                    4.1
# RT_Norm                   0.4
# RTU_Norm                  2.3
# Meta_Norm                 1.3
# Meta_U_Norm               2.3
# IMDB_Norm                 3.0
# Name: 25, dtype: object

# %%
(0.4 + 2.3 + 1.3 + 2.3 + 3.0) / 5
# Out:
# 1.86
